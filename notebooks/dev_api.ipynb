# %%
import requests
import os
import json
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# %%
def get_token():
    load_dotenv('../.env')
    email = "silvi.alcon5@gmail.com"
    password = os.environ.get("password")
    url = "https://openapi.emtmadrid.es/v3/mobilitylabs/user/login/"
    headers = {"email": email, "password" : password}
    response = requests.get(url, headers=headers)
    return response.content

# %%
def get_available_bikes():
    load_dotenv("../.env")
    token = os.environ.get("access_token")
    url = "https://openapi.emtmadrid.es/v3/transport/bicimad/stations/"
    headers = {"accessToken" : token}
    response = requests.get(url, headers = headers).json()
    return response

# %%
stations_real_time = get_available_bikes()
bicimad_real_time = pd.DataFrame(stations_real_time["data"])
bicimad_real_time
# Out:
#      activate                                            address  dock_bikes  \
# 0           1               Avenida del Ensanche de Vallecas, 9,          10
# 1           1  Paseo de la Chopera,33,Comunidad de Madrid España          16
# 2           1                     Paseo de la Castellana nº 122,           4
# 3           1  Paseo de la Castellana nº 164,Comunidad de Mad...           4
# 4           1                                    Guetaria , 84b,          20
# ..        ...                                                ...         ...
# 610         0                     Calle Francisco Balseiro nº 1,           0
# 611         1  237- calle Francisco Balseiro,Comunidad de Mad...           0
# 612         1                 Calle José Abascal frente al nº 2,           1
# 613         0                                  Calle Albelda, 6,           0
# 614         1                                    Calle Ariel, 7,          23
#
#      free_bases                                           geofence  \
# 0            17  {'type': 'Polygon', 'coordinates': [[[-3.61311...
# 1             7  {'type': 'Polygon', 'coordinates': [[[-3.70098...
# 2            19  {'type': 'Polygon', 'coordinates': [[[-3.69138...
# 3            19  {'type': 'Polygon', 'coordinates': [[[-3.69000...
# 4             4  {'type': 'Polygon', 'coordinates': [[[-3.71628...
# ..          ...                                                ...
# 610           0  {'type': 'Polygon', 'coordinates': [[[-3.71111...
# 611           0  {'type': 'Polygon', 'coordinates': [[[-3.71086...
# 612          22  {'type': 'Polygon', 'coordinates': [[[-3.70442...
# 613           0  {'type': 'Polygon', 'coordinates': [[[-3.65795...
# 614           1  {'type': 'Polygon', 'coordinates': [[[-3.68029...
#
#                                               geometry    id  \
# 0    {'type': 'Point', 'coordinates': [-3.61253028,...  2190
# 1    {'type': 'Point', 'coordinates': [-3.700399664...  2205
# 2    {'type': 'Point', 'coordinates': [-3.6908, 40....  2224
# 3    {'type': 'Point', 'coordinates': [-3.6894151, ...  2225
# 4    {'type': 'Point', 'coordinates': [-3.71569102,...  2226
# ..                                                 ...   ...
# 610  {'type': 'Point', 'coordinates': [-3.710525, 4...  1643
# 611  {'type': 'Point', 'coordinates': [-3.7102736, ...  2362
# 612  {'type': 'Point', 'coordinates': [-3.7038333, ...  1607
# 613  {'type': 'Point', 'coordinates': [-3.6573666, ...  2316
# 614  {'type': 'Point', 'coordinates': [-3.679701766...  2064
#
#                                integrator  light  \
# 0    3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      2
# 1    3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      2
# 2    3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      0
# 3    3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      0
# 4    3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      1
# ..                                    ...    ...
# 610  3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      3
# 611  3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      3
# 612  3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      0
# 613  3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      3
# 614  3c34ea72-2a03-4a3c-be97-cf32be4b0ebe      1
#
#                                           name  ...  reservations_count  \
# 0    453 - Avenida del Ensanche de Vallecas, 9  ...                   0
# 1                267 - Paseo de la Chopera, 33  ...                   0
# 2    150 - Castellana frente a Hermanos Pinzón  ...                   0
# 3                          157- Castellana 164  ...                   0
# 4                   395b - 395 - Guetaria  84b  ...                   0
# ..                                         ...  ...                 ...
# 610                       237 - Pablo Iglesias  ...                   0
# 611       1664 - 237- calle Francisco Balseiro  ...                   0
# 612                                201 - Canal  ...                   0
# 613                           528 - Albelda, 6  ...                   0
# 614                       269 - Calle Ariel, 7  ...                   0
#
#     tipo_estacionPBSC  total_bases virtualDelete  virtual_bikes  \
# 0               FIXED           27         False             []
# 1               FIXED           23         False             []
# 2               FIXED           23         False             []
# 3               FIXED           23         False             []
# 4               FIXED           24         False             []
# ..                ...          ...           ...            ...
# 610             FIXED            0         False             []
# 611             FIXED            0         False             []
# 612             FIXED           23         False             []
# 613             FIXED           24         False             []
# 614             FIXED           24         False             []
#
#      virtual_bikes_num code_district  code_suburb geofenced_capacity bikesGo
# 0                    0            18          183               20.0      []
# 1                    0            02          023               20.0      []
# 2                    0            05          051               20.0      []
# 3                    0            05          055               20.0      []
# 4                    0            12          121               20.0      []
# ..                 ...           ...          ...                ...     ...
# 610                  0            06          061                0.0      []
# 611                  0            06          061                0.0      []
# 612                  0            07          075               20.0      []
# 613                  0            15          156               20.0      []
# 614                  0            02          024               20.0      []
#
# [615 rows x 22 columns]
